# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['fontanka',
#  'ginda',
#  'bambous virieux',
#  'manjeshwar',
#  'punta arenas',
#  'jamestown',
#  'bredasdorp',
#  'milove',
#  'yeppoon',
#  'upernavik',
#  'albany',
#  'hobart',
#  'east london',
#  'mahebourg',
#  'lakes entrance',
#  'diffa',
#  'ypsonas',
#  'nemuro',
#  'alice town',
#  'carnarvon',
#  'kavaratti',
#  'saint george',
#  'mataura',
#  'brekstad',
#  'vaini',
#  'hualmay',
#  'hilo',
#  'amderma',
#  'karamay',
#  'taolanaro',
#  'bluff',
#  'majene',
#  'cape town',
#  'chokwe',
#  'pirogovo',
#  'qaanaaq',
#  'ust-barguzin',
#  'airai',
#  'saskylakh',
#  'saintes',
#  'codrington',
#  'paita',
#  'rawson',
#  'burica',
#  'sozopol',
#  'yellowknife',
#  'umred',
#  'vaideeni',
#  'port elizabeth',
#  'ushuaia',
#  'catamarca',
#  'torbay',
#  'kirakira',
#  'zhigansk',
#  'kyzyl-suu',
#  'alamos',
#  'hermanus',
#  'la ronge',
#  'gladstone',
#  'necochea',
#  'port blair',
#  'galle',
#  'barentsburg',
#  'kloulklubed',
#  'adrar',
#  'mayo',
#  'cherskiy',
#  'pevek',
#  'katsuura',
#  'san policarpo',
#  'illoqqortoormiut',
#  'kaitangata',
#  'vila franca do campo',
#  'hay river',
#  'barrow',
#  'bershet',
#  'belushya guba',
#  'sao filipe',
#  'nanortalik',
#  'bairiki',
#  'lamont',
#  'puerto ayora',
#  'satitoa',
#  'kruisfontein',
#  'pacific grove',
#  'goderich',
#  'tukrah',
#  'udachnyy',
#  'bibiani',
#  'bengkulu',
#  'yuanping',
#  'kapaa',
#  'maumere',
#  'puerto maldonado',
#  'boa vista',
#  'rikitea',
#  'harper',
#  'constitucion',
#  'castro',
#  'luwuk',
#  'prince rupert',
#  'arraial do cabo',
#  'busselton',
#  'basirhat',
#  'methoni',
#  'iwanai',
#  'lorengau',
#  'nuuk',
#  'mecca',
#  'valmiera',
#  'sitka',
#  'pacifica',
#  'tofield',
#  'port alfred',
#  'nalut',
#  'vestmannaeyjar',
#  'padang',
#  'iquique',
#  'sur',
#  'tsihombe',
#  'luau',
#  'mgandu',
#  'champerico',
#  'aksarka',
#  'longyearbyen',
#  'salalah',
#  'yakeshi',
#  'port hardy',
#  'mairang',
#  'geraldton',
#  'solvychegodsk',
#  'bethel',
#  'kurchum',
#  'sao joao da barra',
#  'devanhalli',
#  'kharitonovo',
#  'eenhana',
#  'port macquarie',
#  'menongue',
#  'dikson',
#  'maralal',
#  'shimoda',
#  'broken hill',
#  'auki',
#  'yirol',
#  'severo-kurilsk',
#  'golkoy',
#  'georgetown',
#  'lasa',
#  'kintampo',
#  'standerton',
#  'illapel',
#  'miranda',
#  'attawapiskat',
#  'hailar',
#  'cabo san lucas',
#  'atuona',
#  'ribeira grande',
#  'ballina',
#  'mys shmidta',
#  'rumoi',
#  'asfi',
#  'khatanga',
#  'maniitsoq',
#  'guozhen',
#  'esperance',
#  'avera',
#  'cidreira',
#  'clyde river',
#  'coolum beach',
#  'saldanha',
#  'juegang',
#  'colac',
#  'gat',
#  'new norfolk',
#  'talnakh',
#  'aanekoski',
#  'bourail',
#  'bowen',
#  'el sauzal',
#  'ancud',
#  'yining',
#  'pogranichnyy',
#  'tuatapere',
#  'muros',
#  'halalo',
#  'yatou',
#  'lebu',
#  'tongchuan',
#  'tuktoyaktuk',
#  'butaritari',
#  'cayenne',
#  'saint-philippe',
#  'miles city',
#  'baykit',
#  'marawi',
#  'sault sainte marie',
#  'san francisco',
#  'ostersund',
#  'tiksi',
#  'faya',
#  'bac lieu',
#  'manoel urbano',
#  'tonekabon',
#  'okha',
#  'souillac',
#  'estevan',
#  'thompson',
#  'tateyama',
#  'iquitos',
#  'palabuhanratu',
#  'braslav',
#  'tefe',
#  'aklavik',
#  'lompoc',
#  'aflu',
#  'najran',
#  'suez',
#  'amahai',
#  'astoria',
#  'shakhtinsk',
#  'tevaitoa',
#  'kanigoro',
#  'bargal',
#  'mbini',
#  'corning',
#  'thinadhoo',
#  'port said',
#  'ambunti',
#  'svetlogorsk',
#  'entre rios',
#  'grand river south east',
#  'ayni',
#  'scottsboro',
#  'poya',
#  'ossora',
#  'hafizabad',
#  'donetsk',
#  'bozuyuk',
#  'comodoro rivadavia',
#  'lavrentiya',
#  'ilulissat',
#  'boyolangu',
#  'chokurdakh',
#  'ulu-telyak',
#  'batemans bay',
#  'dzaoudzi',
#  'beringovskiy',
#  'ahipara',
#  'chernyshevsk',
#  'rajapur',
#  'noumea',
#  'husavik',
#  'beloha',
#  'intipuca',
#  'cockburn town',
#  'bossangoa',
#  'anadyr',
#  'sorvag',
#  'gwadar',
#  'garden city',
#  'katobu',
#  'russell',
#  'kyra',
#  'mansa',
#  'rodrigues alves',
#  'bulri',
#  'jalu',
#  'ngukurr',
#  'kirksville',
#  'si racha',
#  'abu road',
#  'yamada',
#  'katangli',
#  'vilcun',
#  'meru',
#  'raudeberg',
#  'hithadhoo',
#  'lucea',
#  'victoria',
#  'cuajinicuilapa',
#  'bay saint louis',
#  'lar',
#  'haines junction',
#  'wattegama',
#  'fort nelson',
#  'antalaha',
#  'khorramshahr',
#  'honningsvag',
#  'plyussa',
#  'port-gentil',
#  'kavieng',
#  'doha',
#  'pisco',
#  'fairbanks',
#  'carballo',
#  'vardo',
#  'ketchikan',
#  'bongandanga',
#  'hermagor',
#  'chuy',
#  'coihaique',
#  'faanui',
#  'port keats',
#  'skovorodino',
#  'nurobod',
#  'touros',
#  'westport',
#  'stawell',
#  'mount isa',
#  'la roda',
#  'nizhneyansk',
#  'edd',
#  'kabalo',
#  'boysun',
#  'ranghulu',
#  'namatanai',
#  'yanam',
#  'nikolskoye',
#  'moberly',
#  'benguela',
#  'santo amaro da imperatriz',
#  'narsaq',
#  'murliganj',
#  'flagstaff',
#  'marcona',
#  'ponta do sol',
#  'xiaolingwei',
#  'sangar',
#  'linxia',
#  'tabiauea',
#  'flin flon',
#  'mackay',
#  'sentyabrskiy',
#  'viligili',
#  'saint anthony',
#  'tabou',
#  'deputatskiy',
#  'kodiak',
#  'samusu',
#  'pignon',
#  'provideniya',
#  'labuan',
#  'broome',
#  'xining',
#  'portland',
#  'sirjan',
#  'shirokiy',
#  'temir',
#  'la rioja',
#  'moron',
#  'bonavista',
#  'celestun',
#  'tatawin',
#  'ladario',
#  'cuamba',
#  'samalaeulu',
#  'dukat',
#  'yulara',
#  'apiai',
#  'magadan',
#  'chase',
#  'mantua',
#  'salina',
#  'khani',
#  'lichtenburg',
#  'linchuan',
#  'mar del plata',
#  'mokhsogollokh',
#  'hambantota',
#  'astana',
#  'barranca',
#  'gizo',
#  'safaqis',
#  'tura',
#  'evensk',
#  'fortuna',
#  'iracoubo',
#  'tirschenreuth',
#  'glyadyanskoye',
#  'vilyuysk',
#  'smithers',
#  'poum',
#  'altonia',
#  'sola',
#  'san quintin',
#  'sinnamary',
#  'tidore',
#  'isangel',
#  'price',
#  'berlevag',
#  'naze',
#  'dekar',
#  'cedar city',
#  'san patricio',
#  'preobrazheniye',
#  'carcassonne',
#  'norman wells',
#  'newport',
#  'falealupo',
#  'asau',
#  'smoky lake',
#  'basoko',
#  'orotukan',
#  'nekrasovka',
#  'inirida',
#  'denpasar',
#  'puerto castilla',
#  'ayagoz',
#  'disraeli',
#  'xambioa',
#  'nyurba',
#  'saleaula',
#  'jhang',
#  'baicheng',
#  'zhuhai',
#  'charters towers',
#  'kununurra',
#  'sambava',
#  'vestmanna',
#  'barcelona',
#  'muzhi',
#  'nishihara',
#  'iqaluit',
#  'palmer',
#  'bonthe',
#  'havre-saint-pierre',
#  'damghan',
#  'rafaela',
#  'papara',
#  'kaeo',
#  'arlit',
#  'kijang',
#  'pachmarhi',
#  'itaguai',
#  'lawrenceburg',
#  'machico',
#  'beidao',
#  'balykshi',
#  'hamilton',
#  'kisangani',
#  'tasiilaq',
#  'laguna',
#  'paamiut',
#  'utiroa',
#  'waspan',
#  'mahalapye',
#  'leshukonskoye',
#  'vadgaon',
#  'conceicao do araguaia',
#  'homer',
#  'arona',
#  'erdenet',
#  'hvide sande',
#  'ustka',
#  'nakhon nayok',
#  'alofi',
#  'cabra',
#  'kamaishi',
#  'shache',
#  'luderitz',
#  'puerto penasco',
#  'mehamn',
#  'ilhabela',
#  'acurenam',
#  'reconquista',
#  'kargopol',
#  'erzin',
#  'zeya',
#  'lagoa',
#  'coquimbo',
#  'buchanan',
#  'mount gambier',
#  'arroyo',
#  'puerto escondido',
#  'kilindoni',
#  'havoysund',
#  'avarua',
#  'atambua',
#  'ishigaki',
#  'naryan-mar',
#  'pitimbu',
#  'port hedland',
#  'kutum',
#  'kuche',
#  'kieta',
#  'waipawa',
#  'itarema',
#  'zaysan',
#  'camacha',
#  'mouzouras',
#  'adelanto',
#  'puri',
#  'gap',
#  'hargeysa',
#  'aktau',
#  'tucuman',
#  'crestview',
#  'chara',
#  'santiago del estero',
#  'san rafael del sur',
#  'cortes',
#  'kralendijk',
#  'sorland',
#  'karratha',
#  'ust-kulom',
#  'burnie',
#  'dayong',
#  'macheng',
#  'ust-tsilma',
#  'kuznechnoye',
#  'yushan',
#  'tawkar',
#  'kahului',
#  'yumen',
#  'bandraboua',
#  'diebougou',
#  'dingle',
#  'jega',
#  'sayyan',
#  'rocha',
#  'hasaki',
#  'kargil',
#  'pochutla',
#  'mooi river',
#  'tiznit',
#  'ust-tarka',
#  'alice springs',
#  'kharp',
#  'compiegne',
#  'bonfim',
#  'rio gallegos',
#  'wulanhaote',
#  'santa adelia',
#  'waingapu',
#  'gamba',
#  'dolores',
#  'abu dhabi',
#  'montepuez',
#  'halifax',
#  'ojinaga',
#  'qarqin',
#  'praia da vitoria',
#  'soe',
#  'ixtapa',
#  'changtu',
#  'emerald',
#  'male',
#  'kargasok',
#  'namibe',
#  'galesong',
#  'araouane',
#  'praya',
#  'quatre cocos',
#  'ternate',
#  'verkh-usugli',
#  'olafsvik',
#  'krasnoselkup',
#  'krasnoye',
#  'ruteng',
#  'lumphat',
#  'tilichiki',
#  'sobolevo',
#  'half moon bay',
#  'gambela',
#  'aalestrup',
#  'port lincoln',
#  'bud',
#  'kirkwood',
#  'sabha',
#  'dunedin',
#  'presidencia roque saenz pena',
#  'bandarbeyla',
#  'vila velha',
#  'vaitupu',
#  'yuzhnouralsk',
#  'grindavik',
#  'kamakwie',
#  'saryshagan',
#  'khonsa',
#  'guerrero negro',
#  'riyadh',
#  'arrifes',
#  'chicama',
#  'huarmey',
#  'marsa matruh',
#  'derzhavinsk',
#  'achutupo',
#  'taltal',
#  'penzance',
#  'saint-pierre',
#  'rungata',
#  'grand forks',
#  'shitanjing',
#  'ulagan',
#  'alugan',
#  'hobyo',
#  'bergen',
#  'lokosovo',
#  'grand gaube',
#  'hami',
#  'tautira',
#  'taoudenni',
#  'businga',
#  'pangoa',
#  'oistins',
#  'kemalpasa',
#  'aswan',
#  'port lavaca',
#  'haflong',
#  'high level',
#  'kristiansund',
#  'kamphaeng phet',
#  'leningradskiy',
#  'kangaatsiaq',
#  'hokitika',
#  'niedernhausen',
#  'hanyang',
#  'enid',
#  'nova olinda do norte',
#  'kamenka',
#  'santa cruz',
#  'sfantu gheorghe',
#  'vanimo',
#  'saposoa',
#  'madhipura',
#  'santa marta',
#  'yaan',
#  'jeremie',
#  'mezen',
#  'inyonga',
#  'kohlu',
#  'emilio carranza',
#  'kozulka',
#  'almaznyy',
#  'shenjiamen',
#  'merauke',
#  'ojhar',
#  'coos bay',
#  'klaksvik',
#  'porto novo',
#  'teya',
#  'oranmore',
#  'aasiaat',
#  'vao',
#  'xapuri',
#  'savinka',
#  'pangnirtung',
#  'santa maria',
#  'meadow lake',
#  'birin',
#  'college',
#  'puerto del rosario',
#  'shubarshi',
#  'slave lake',
#  'walvis bay',
#  'santa eulalia del rio',
#  'todos santos',
#  'sioux lookout',
#  'sumbawa',
#  'igarka',
#  'pangody',
#  'littleton',
#  'barcelos',
#  'boca do acre',
#  'cividale del friuli',
#  'chumikan',
#  'nisia floresta',
#  'somerset',
#  'bindura',
#  'darhan',
#  'wakkanai',
#  'khasan',
#  'shiloh',
#  'cazaje',
#  'richards bay',
#  'paidha',
#  'ekibastuz',
#  'den helder',
#  'terrace bay',
#  'gunjur',
#  'tessalit',
#  'paradwip',
#  'mwense',
#  'bathsheba',
#  'hanzhong',
#  'kartarpur',
#  'juneau',
#  'seagoville',
#  'jaque',
#  'buala',
#  'areosa',
#  'tortosa',
#  'tammisaari',
#  'kalmunai',
#  'yar-sale',
#  'talcahuano',
#  'vestbygda',
#  'ceyhan',
#  'trincomalee',
#  'skowhegan',
#  'margate',
#  'srednekolymsk',
#  'tumannyy',
#  'gamboula',
#  'paka',
#  'sahrak',
#  'flinders',
#  'bistret',
#  'zlobin',
#  'visnes',
#  'abu samrah',
#  'bubaque',
#  'tutoia',
#  'warqla',
#  'haibowan',
#  'aracati',
#  'black forest',
#  'bilibino',
#  'lichinga',
#  'muncar',
#  'pakxan',
#  'kenora',
#  'taunggyi',
#  'peno',
#  'huazolotitlan',
#  'marshfield',
#  'hirara',
#  'anloga',
#  'trairi',
#  'palotina',
#  'ambon',
#  'guiglo',
#  'port hawkesbury',
#  'san esteban',
#  'jaguarao',
#  'wewak',
#  'savannakhet',
#  'porbandar',
#  'san borja',
#  'muroto',
#  'sena madureira',
#  'mizpe ramon',
#  'inderborskiy',
#  'upata',
#  'lewistown',
#  'korla']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#city_url = url + "&q=" + city.replace(" ","+")
#city_url
#city_weather = requests.get(city_url).json()
#city_weather
#city_description = city_weather['weather'][0]['description']
#city_description

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fontanka
# Processing Record 2 of Set 1 | ginda
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | manjeshwar
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | milove
# Processing Record 9 of Set 1 | yeppoon
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | lakes entrance
# Processing Record 16 of Set 1 | diffa
# Processing Record 17 of Set 1 | ypsonas
# Processing Record 18 of Set 1 | nemuro
# Processing Record 19 of Set 1 | alice town
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | kavaratti
# Processing Record 22 of Set 1 | saint george
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | brekstad
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | hualmay
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | majene
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | chokwe
# Processing Record 35 of Set 1 | pirogovo
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | ust-barguzin
# Processing Record 38 of Set 1 | airai
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | saintes
# Processing Record 41 of Set 1 | codrington
# Processing Record 42 of Set 1 | paita
# Processing Record 43 of Set 1 | rawson
# Processing Record 44 of Set 1 | burica
# City not found. Skipping...
# Processing Record 45 of Set 1 | sozopol
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | umred
# Processing Record 48 of Set 1 | vaideeni
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | catamarca
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | kirakira
# Processing Record 4 of Set 2 | zhigansk
# Processing Record 5 of Set 2 | kyzyl-suu
# Processing Record 6 of Set 2 | alamos
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | la ronge
# Processing Record 9 of Set 2 | gladstone
# Processing Record 10 of Set 2 | necochea
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | galle
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | kloulklubed
# Processing Record 15 of Set 2 | adrar
# Processing Record 16 of Set 2 | mayo
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | katsuura
# Processing Record 20 of Set 2 | san policarpo
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | kaitangata
# Processing Record 23 of Set 2 | vila franca do campo
# Processing Record 24 of Set 2 | hay river
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | bershet
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | bairiki
# Processing Record 31 of Set 2 | lamont
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | goderich
# Processing Record 37 of Set 2 | tukrah
# Processing Record 38 of Set 2 | udachnyy
# Processing Record 39 of Set 2 | bibiani
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | yuanping
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | maumere
# Processing Record 44 of Set 2 | puerto maldonado
# Processing Record 45 of Set 2 | boa vista
# Processing Record 46 of Set 2 | rikitea
# Processing Record 47 of Set 2 | harper
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | luwuk
# Processing Record 1 of Set 3 | prince rupert
# Processing Record 2 of Set 3 | arraial do cabo
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | basirhat
# Processing Record 5 of Set 3 | methoni
# Processing Record 6 of Set 3 | iwanai
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | nuuk
# Processing Record 9 of Set 3 | mecca
# Processing Record 10 of Set 3 | valmiera
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | pacifica
# Processing Record 13 of Set 3 | tofield
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | nalut
# Processing Record 16 of Set 3 | vestmannaeyjar
# Processing Record 17 of Set 3 | padang
# Processing Record 18 of Set 3 | iquique
# Processing Record 19 of Set 3 | sur
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | luau
# Processing Record 22 of Set 3 | mgandu
# Processing Record 23 of Set 3 | champerico
# Processing Record 24 of Set 3 | aksarka
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | yakeshi
# Processing Record 28 of Set 3 | port hardy
# Processing Record 29 of Set 3 | mairang
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | solvychegodsk
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | kurchum
# Processing Record 34 of Set 3 | sao joao da barra
# Processing Record 35 of Set 3 | devanhalli
# Processing Record 36 of Set 3 | kharitonovo
# Processing Record 37 of Set 3 | eenhana
# Processing Record 38 of Set 3 | port macquarie
# Processing Record 39 of Set 3 | menongue
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | maralal
# Processing Record 42 of Set 3 | shimoda
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | auki
# Processing Record 45 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 3 | severo-kurilsk
# Processing Record 47 of Set 3 | golkoy
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | lasa
# Processing Record 50 of Set 3 | kintampo
# Processing Record 1 of Set 4 | standerton
# Processing Record 2 of Set 4 | illapel
# Processing Record 3 of Set 4 | miranda
# Processing Record 4 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 4 | hailar
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | atuona
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | ballina
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | rumoi
# Processing Record 12 of Set 4 | asfi
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | maniitsoq
# Processing Record 15 of Set 4 | guozhen
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | avera
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | clyde river
# Processing Record 20 of Set 4 | coolum beach
# Processing Record 21 of Set 4 | saldanha
# Processing Record 22 of Set 4 | juegang
# Processing Record 23 of Set 4 | colac
# Processing Record 24 of Set 4 | gat
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | talnakh
# Processing Record 27 of Set 4 | aanekoski
# Processing Record 28 of Set 4 | bourail
# Processing Record 29 of Set 4 | bowen
# Processing Record 30 of Set 4 | el sauzal
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | yining
# Processing Record 33 of Set 4 | pogranichnyy
# Processing Record 34 of Set 4 | tuatapere
# Processing Record 35 of Set 4 | muros
# Processing Record 36 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 4 | yatou
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | tongchuan
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | butaritari
# Processing Record 42 of Set 4 | cayenne
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | miles city
# Processing Record 45 of Set 4 | baykit
# Processing Record 46 of Set 4 | marawi
# Processing Record 47 of Set 4 | sault sainte marie
# Processing Record 48 of Set 4 | san francisco
# Processing Record 49 of Set 4 | ostersund
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | faya
# Processing Record 2 of Set 5 | bac lieu
# Processing Record 3 of Set 5 | manoel urbano
# Processing Record 4 of Set 5 | tonekabon
# Processing Record 5 of Set 5 | okha
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | estevan
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | tateyama
# Processing Record 10 of Set 5 | iquitos
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | braslav
# City not found. Skipping...
# Processing Record 13 of Set 5 | tefe
# Processing Record 14 of Set 5 | aklavik
# Processing Record 15 of Set 5 | lompoc
# Processing Record 16 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 5 | najran
# Processing Record 18 of Set 5 | suez
# Processing Record 19 of Set 5 | amahai
# Processing Record 20 of Set 5 | astoria
# Processing Record 21 of Set 5 | shakhtinsk
# Processing Record 22 of Set 5 | tevaitoa
# Processing Record 23 of Set 5 | kanigoro
# Processing Record 24 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 5 | mbini
# Processing Record 26 of Set 5 | corning
# Processing Record 27 of Set 5 | thinadhoo
# Processing Record 28 of Set 5 | port said
# Processing Record 29 of Set 5 | ambunti
# Processing Record 30 of Set 5 | svetlogorsk
# Processing Record 31 of Set 5 | entre rios
# Processing Record 32 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | ayni
# Processing Record 34 of Set 5 | scottsboro
# Processing Record 35 of Set 5 | poya
# Processing Record 36 of Set 5 | ossora
# Processing Record 37 of Set 5 | hafizabad
# Processing Record 38 of Set 5 | donetsk
# Processing Record 39 of Set 5 | bozuyuk
# Processing Record 40 of Set 5 | comodoro rivadavia
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | boyolangu
# Processing Record 44 of Set 5 | chokurdakh
# Processing Record 45 of Set 5 | ulu-telyak
# Processing Record 46 of Set 5 | batemans bay
# Processing Record 47 of Set 5 | dzaoudzi
# Processing Record 48 of Set 5 | beringovskiy
# Processing Record 49 of Set 5 | ahipara
# Processing Record 50 of Set 5 | chernyshevsk
# Processing Record 1 of Set 6 | rajapur
# Processing Record 2 of Set 6 | noumea
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | beloha
# Processing Record 5 of Set 6 | intipuca
# Processing Record 6 of Set 6 | cockburn town
# Processing Record 7 of Set 6 | bossangoa
# Processing Record 8 of Set 6 | anadyr
# Processing Record 9 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 6 | gwadar
# Processing Record 11 of Set 6 | garden city
# Processing Record 12 of Set 6 | katobu
# Processing Record 13 of Set 6 | russell
# Processing Record 14 of Set 6 | kyra
# Processing Record 15 of Set 6 | mansa
# Processing Record 16 of Set 6 | rodrigues alves
# Processing Record 17 of Set 6 | bulri
# Processing Record 18 of Set 6 | jalu
# Processing Record 19 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 6 | kirksville
# Processing Record 21 of Set 6 | si racha
# Processing Record 22 of Set 6 | abu road
# Processing Record 23 of Set 6 | yamada
# Processing Record 24 of Set 6 | katangli
# Processing Record 25 of Set 6 | vilcun
# Processing Record 26 of Set 6 | meru
# Processing Record 27 of Set 6 | raudeberg
# Processing Record 28 of Set 6 | hithadhoo
# Processing Record 29 of Set 6 | lucea
# Processing Record 30 of Set 6 | victoria
# Processing Record 31 of Set 6 | cuajinicuilapa
# Processing Record 32 of Set 6 | bay saint louis
# Processing Record 33 of Set 6 | lar
# Processing Record 34 of Set 6 | haines junction
# Processing Record 35 of Set 6 | wattegama
# Processing Record 36 of Set 6 | fort nelson
# Processing Record 37 of Set 6 | antalaha
# Processing Record 38 of Set 6 | khorramshahr
# Processing Record 39 of Set 6 | honningsvag
# Processing Record 40 of Set 6 | plyussa
# Processing Record 41 of Set 6 | port-gentil
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | doha
# Processing Record 44 of Set 6 | pisco
# Processing Record 45 of Set 6 | fairbanks
# Processing Record 46 of Set 6 | carballo
# Processing Record 47 of Set 6 | vardo
# Processing Record 48 of Set 6 | ketchikan
# Processing Record 49 of Set 6 | bongandanga
# Processing Record 50 of Set 6 | hermagor
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | coihaique
# Processing Record 3 of Set 7 | faanui
# Processing Record 4 of Set 7 | port keats
# Processing Record 5 of Set 7 | skovorodino
# Processing Record 6 of Set 7 | nurobod
# Processing Record 7 of Set 7 | touros
# Processing Record 8 of Set 7 | westport
# Processing Record 9 of Set 7 | stawell
# Processing Record 10 of Set 7 | mount isa
# Processing Record 11 of Set 7 | la roda
# Processing Record 12 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 7 | edd
# Processing Record 14 of Set 7 | kabalo
# Processing Record 15 of Set 7 | boysun
# Processing Record 16 of Set 7 | ranghulu
# Processing Record 17 of Set 7 | namatanai
# Processing Record 18 of Set 7 | yanam
# Processing Record 19 of Set 7 | nikolskoye
# Processing Record 20 of Set 7 | moberly
# Processing Record 21 of Set 7 | benguela
# Processing Record 22 of Set 7 | santo amaro da imperatriz
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | murliganj
# Processing Record 25 of Set 7 | flagstaff
# Processing Record 26 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 7 | ponta do sol
# Processing Record 28 of Set 7 | xiaolingwei
# Processing Record 29 of Set 7 | sangar
# Processing Record 30 of Set 7 | linxia
# Processing Record 31 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 7 | flin flon
# Processing Record 33 of Set 7 | mackay
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint anthony
# Processing Record 37 of Set 7 | tabou
# Processing Record 38 of Set 7 | deputatskiy
# Processing Record 39 of Set 7 | kodiak
# Processing Record 40 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 7 | pignon
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | labuan
# Processing Record 44 of Set 7 | broome
# Processing Record 45 of Set 7 | xining
# Processing Record 46 of Set 7 | portland
# Processing Record 47 of Set 7 | sirjan
# Processing Record 48 of Set 7 | shirokiy
# Processing Record 49 of Set 7 | temir
# Processing Record 50 of Set 7 | la rioja
# Processing Record 1 of Set 8 | moron
# Processing Record 2 of Set 8 | bonavista
# Processing Record 3 of Set 8 | celestun
# Processing Record 4 of Set 8 | tatawin
# Processing Record 5 of Set 8 | ladario
# Processing Record 6 of Set 8 | cuamba
# Processing Record 7 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 8 | dukat
# Processing Record 9 of Set 8 | yulara
# Processing Record 10 of Set 8 | apiai
# Processing Record 11 of Set 8 | magadan
# Processing Record 12 of Set 8 | chase
# Processing Record 13 of Set 8 | mantua
# Processing Record 14 of Set 8 | salina
# Processing Record 15 of Set 8 | khani
# Processing Record 16 of Set 8 | lichtenburg
# Processing Record 17 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 18 of Set 8 | mar del plata
# Processing Record 19 of Set 8 | mokhsogollokh
# Processing Record 20 of Set 8 | hambantota
# Processing Record 21 of Set 8 | astana
# Processing Record 22 of Set 8 | barranca
# Processing Record 23 of Set 8 | gizo
# Processing Record 24 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 25 of Set 8 | tura
# Processing Record 26 of Set 8 | evensk
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | iracoubo
# Processing Record 29 of Set 8 | tirschenreuth
# Processing Record 30 of Set 8 | glyadyanskoye
# Processing Record 31 of Set 8 | vilyuysk
# Processing Record 32 of Set 8 | smithers
# Processing Record 33 of Set 8 | poum
# Processing Record 34 of Set 8 | altonia
# City not found. Skipping...
# Processing Record 35 of Set 8 | sola
# Processing Record 36 of Set 8 | san quintin
# Processing Record 37 of Set 8 | sinnamary
# Processing Record 38 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 8 | isangel
# Processing Record 40 of Set 8 | price
# Processing Record 41 of Set 8 | berlevag
# Processing Record 42 of Set 8 | naze
# Processing Record 43 of Set 8 | dekar
# Processing Record 44 of Set 8 | cedar city
# Processing Record 45 of Set 8 | san patricio
# Processing Record 46 of Set 8 | preobrazheniye
# Processing Record 47 of Set 8 | carcassonne
# Processing Record 48 of Set 8 | norman wells
# Processing Record 49 of Set 8 | newport
# Processing Record 50 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 9 | asau
# Processing Record 2 of Set 9 | smoky lake
# Processing Record 3 of Set 9 | basoko
# Processing Record 4 of Set 9 | orotukan
# Processing Record 5 of Set 9 | nekrasovka
# Processing Record 6 of Set 9 | inirida
# Processing Record 7 of Set 9 | denpasar
# Processing Record 8 of Set 9 | puerto castilla
# Processing Record 9 of Set 9 | ayagoz
# Processing Record 10 of Set 9 | disraeli
# Processing Record 11 of Set 9 | xambioa
# Processing Record 12 of Set 9 | nyurba
# Processing Record 13 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 9 | jhang
# Processing Record 15 of Set 9 | baicheng
# Processing Record 16 of Set 9 | zhuhai
# Processing Record 17 of Set 9 | charters towers
# Processing Record 18 of Set 9 | kununurra
# Processing Record 19 of Set 9 | sambava
# Processing Record 20 of Set 9 | vestmanna
# Processing Record 21 of Set 9 | barcelona
# Processing Record 22 of Set 9 | muzhi
# Processing Record 23 of Set 9 | nishihara
# Processing Record 24 of Set 9 | iqaluit
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | bonthe
# Processing Record 27 of Set 9 | havre-saint-pierre
# Processing Record 28 of Set 9 | damghan
# Processing Record 29 of Set 9 | rafaela
# Processing Record 30 of Set 9 | papara
# Processing Record 31 of Set 9 | kaeo
# Processing Record 32 of Set 9 | arlit
# Processing Record 33 of Set 9 | kijang
# Processing Record 34 of Set 9 | pachmarhi
# Processing Record 35 of Set 9 | itaguai
# Processing Record 36 of Set 9 | lawrenceburg
# Processing Record 37 of Set 9 | machico
# Processing Record 38 of Set 9 | beidao
# Processing Record 39 of Set 9 | balykshi
# Processing Record 40 of Set 9 | hamilton
# Processing Record 41 of Set 9 | kisangani
# Processing Record 42 of Set 9 | tasiilaq
# Processing Record 43 of Set 9 | laguna
# Processing Record 44 of Set 9 | paamiut
# Processing Record 45 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 9 | waspan
# Processing Record 47 of Set 9 | mahalapye
# Processing Record 48 of Set 9 | leshukonskoye
# Processing Record 49 of Set 9 | vadgaon
# Processing Record 50 of Set 9 | conceicao do araguaia
# Processing Record 1 of Set 10 | homer
# Processing Record 2 of Set 10 | arona
# Processing Record 3 of Set 10 | erdenet
# Processing Record 4 of Set 10 | hvide sande
# Processing Record 5 of Set 10 | ustka
# Processing Record 6 of Set 10 | nakhon nayok
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | cabra
# Processing Record 9 of Set 10 | kamaishi
# Processing Record 10 of Set 10 | shache
# Processing Record 11 of Set 10 | luderitz
# Processing Record 12 of Set 10 | puerto penasco
# Processing Record 13 of Set 10 | mehamn
# Processing Record 14 of Set 10 | ilhabela
# Processing Record 15 of Set 10 | acurenam
# Processing Record 16 of Set 10 | reconquista
# Processing Record 17 of Set 10 | kargopol
# Processing Record 18 of Set 10 | erzin
# Processing Record 19 of Set 10 | zeya
# Processing Record 20 of Set 10 | lagoa
# Processing Record 21 of Set 10 | coquimbo
# Processing Record 22 of Set 10 | buchanan
# Processing Record 23 of Set 10 | mount gambier
# Processing Record 24 of Set 10 | arroyo
# Processing Record 25 of Set 10 | puerto escondido
# Processing Record 26 of Set 10 | kilindoni
# Processing Record 27 of Set 10 | havoysund
# Processing Record 28 of Set 10 | avarua
# Processing Record 29 of Set 10 | atambua
# Processing Record 30 of Set 10 | ishigaki
# Processing Record 31 of Set 10 | naryan-mar
# Processing Record 32 of Set 10 | pitimbu
# Processing Record 33 of Set 10 | port hedland
# Processing Record 34 of Set 10 | kutum
# Processing Record 35 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 10 | kieta
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | itarema
# Processing Record 39 of Set 10 | zaysan
# Processing Record 40 of Set 10 | camacha
# Processing Record 41 of Set 10 | mouzouras
# Processing Record 42 of Set 10 | adelanto
# Processing Record 43 of Set 10 | puri
# Processing Record 44 of Set 10 | gap
# Processing Record 45 of Set 10 | hargeysa
# Processing Record 46 of Set 10 | aktau
# Processing Record 47 of Set 10 | tucuman
# Processing Record 48 of Set 10 | crestview
# Processing Record 49 of Set 10 | chara
# Processing Record 50 of Set 10 | santiago del estero
# Processing Record 1 of Set 11 | san rafael del sur
# Processing Record 2 of Set 11 | cortes
# Processing Record 3 of Set 11 | kralendijk
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | ust-kulom
# Processing Record 7 of Set 11 | burnie
# Processing Record 8 of Set 11 | dayong
# Processing Record 9 of Set 11 | macheng
# Processing Record 10 of Set 11 | ust-tsilma
# Processing Record 11 of Set 11 | kuznechnoye
# Processing Record 12 of Set 11 | yushan
# Processing Record 13 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 11 | kahului
# Processing Record 15 of Set 11 | yumen
# Processing Record 16 of Set 11 | bandraboua
# Processing Record 17 of Set 11 | diebougou
# Processing Record 18 of Set 11 | dingle
# Processing Record 19 of Set 11 | jega
# Processing Record 20 of Set 11 | sayyan
# Processing Record 21 of Set 11 | rocha
# Processing Record 22 of Set 11 | hasaki
# Processing Record 23 of Set 11 | kargil
# Processing Record 24 of Set 11 | pochutla
# Processing Record 25 of Set 11 | mooi river
# City not found. Skipping...
# Processing Record 26 of Set 11 | tiznit
# Processing Record 27 of Set 11 | ust-tarka
# Processing Record 28 of Set 11 | alice springs
# Processing Record 29 of Set 11 | kharp
# Processing Record 30 of Set 11 | compiegne
# Processing Record 31 of Set 11 | bonfim
# Processing Record 32 of Set 11 | rio gallegos
# Processing Record 33 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 11 | santa adelia
# Processing Record 35 of Set 11 | waingapu
# Processing Record 36 of Set 11 | gamba
# Processing Record 37 of Set 11 | dolores
# Processing Record 38 of Set 11 | abu dhabi
# Processing Record 39 of Set 11 | montepuez
# Processing Record 40 of Set 11 | halifax
# Processing Record 41 of Set 11 | ojinaga
# Processing Record 42 of Set 11 | qarqin
# Processing Record 43 of Set 11 | praia da vitoria
# Processing Record 44 of Set 11 | soe
# Processing Record 45 of Set 11 | ixtapa
# Processing Record 46 of Set 11 | changtu
# Processing Record 47 of Set 11 | emerald
# Processing Record 48 of Set 11 | male
# Processing Record 49 of Set 11 | kargasok
# Processing Record 50 of Set 11 | namibe
# Processing Record 1 of Set 12 | galesong
# Processing Record 2 of Set 12 | araouane
# Processing Record 3 of Set 12 | praya
# Processing Record 4 of Set 12 | quatre cocos
# Processing Record 5 of Set 12 | ternate
# Processing Record 6 of Set 12 | verkh-usugli
# Processing Record 7 of Set 12 | olafsvik
# Processing Record 8 of Set 12 | krasnoselkup
# Processing Record 9 of Set 12 | krasnoye
# Processing Record 10 of Set 12 | ruteng
# Processing Record 11 of Set 12 | lumphat
# Processing Record 12 of Set 12 | tilichiki
# Processing Record 13 of Set 12 | sobolevo
# Processing Record 14 of Set 12 | half moon bay
# Processing Record 15 of Set 12 | gambela
# Processing Record 16 of Set 12 | aalestrup
# City not found. Skipping...
# Processing Record 17 of Set 12 | port lincoln
# Processing Record 18 of Set 12 | bud
# Processing Record 19 of Set 12 | kirkwood
# Processing Record 20 of Set 12 | sabha
# Processing Record 21 of Set 12 | dunedin
# Processing Record 22 of Set 12 | presidencia roque saenz pena
# Processing Record 23 of Set 12 | bandarbeyla
# Processing Record 24 of Set 12 | vila velha
# Processing Record 25 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 12 | yuzhnouralsk
# Processing Record 27 of Set 12 | grindavik
# Processing Record 28 of Set 12 | kamakwie
# Processing Record 29 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 30 of Set 12 | khonsa
# Processing Record 31 of Set 12 | guerrero negro
# Processing Record 32 of Set 12 | riyadh
# Processing Record 33 of Set 12 | arrifes
# Processing Record 34 of Set 12 | chicama
# Processing Record 35 of Set 12 | huarmey
# Processing Record 36 of Set 12 | marsa matruh
# Processing Record 37 of Set 12 | derzhavinsk
# Processing Record 38 of Set 12 | achutupo
# Processing Record 39 of Set 12 | taltal
# Processing Record 40 of Set 12 | penzance
# Processing Record 41 of Set 12 | saint-pierre
# Processing Record 42 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 12 | grand forks
# Processing Record 44 of Set 12 | shitanjing
# Processing Record 45 of Set 12 | ulagan
# Processing Record 46 of Set 12 | alugan
# Processing Record 47 of Set 12 | hobyo
# Processing Record 48 of Set 12 | bergen
# Processing Record 49 of Set 12 | lokosovo
# Processing Record 50 of Set 12 | grand gaube
# Processing Record 1 of Set 13 | hami
# Processing Record 2 of Set 13 | tautira
# Processing Record 3 of Set 13 | taoudenni
# Processing Record 4 of Set 13 | businga
# Processing Record 5 of Set 13 | pangoa
# Processing Record 6 of Set 13 | oistins
# Processing Record 7 of Set 13 | kemalpasa
# Processing Record 8 of Set 13 | aswan
# Processing Record 9 of Set 13 | port lavaca
# Processing Record 10 of Set 13 | haflong
# Processing Record 11 of Set 13 | high level
# Processing Record 12 of Set 13 | kristiansund
# Processing Record 13 of Set 13 | kamphaeng phet
# Processing Record 14 of Set 13 | leningradskiy
# Processing Record 15 of Set 13 | kangaatsiaq
# Processing Record 16 of Set 13 | hokitika
# Processing Record 17 of Set 13 | niedernhausen
# Processing Record 18 of Set 13 | hanyang
# Processing Record 19 of Set 13 | enid
# Processing Record 20 of Set 13 | nova olinda do norte
# Processing Record 21 of Set 13 | kamenka
# Processing Record 22 of Set 13 | santa cruz
# Processing Record 23 of Set 13 | sfantu gheorghe
# Processing Record 24 of Set 13 | vanimo
# Processing Record 25 of Set 13 | saposoa
# Processing Record 26 of Set 13 | madhipura
# Processing Record 27 of Set 13 | santa marta
# Processing Record 28 of Set 13 | yaan
# Processing Record 29 of Set 13 | jeremie
# Processing Record 30 of Set 13 | mezen
# Processing Record 31 of Set 13 | inyonga
# Processing Record 32 of Set 13 | kohlu
# Processing Record 33 of Set 13 | emilio carranza
# Processing Record 34 of Set 13 | kozulka
# Processing Record 35 of Set 13 | almaznyy
# Processing Record 36 of Set 13 | shenjiamen
# Processing Record 37 of Set 13 | merauke
# Processing Record 38 of Set 13 | ojhar
# Processing Record 39 of Set 13 | coos bay
# Processing Record 40 of Set 13 | klaksvik
# Processing Record 41 of Set 13 | porto novo
# Processing Record 42 of Set 13 | teya
# Processing Record 43 of Set 13 | oranmore
# Processing Record 44 of Set 13 | aasiaat
# Processing Record 45 of Set 13 | vao
# Processing Record 46 of Set 13 | xapuri
# Processing Record 47 of Set 13 | savinka
# Processing Record 48 of Set 13 | pangnirtung
# Processing Record 49 of Set 13 | santa maria
# Processing Record 50 of Set 13 | meadow lake
# Processing Record 1 of Set 14 | birin
# Processing Record 2 of Set 14 | college
# Processing Record 3 of Set 14 | puerto del rosario
# Processing Record 4 of Set 14 | shubarshi
# Processing Record 5 of Set 14 | slave lake
# Processing Record 6 of Set 14 | walvis bay
# Processing Record 7 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 8 of Set 14 | todos santos
# Processing Record 9 of Set 14 | sioux lookout
# Processing Record 10 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 14 | igarka
# Processing Record 12 of Set 14 | pangody
# Processing Record 13 of Set 14 | littleton
# Processing Record 14 of Set 14 | barcelos
# Processing Record 15 of Set 14 | boca do acre
# Processing Record 16 of Set 14 | cividale del friuli
# Processing Record 17 of Set 14 | chumikan
# Processing Record 18 of Set 14 | nisia floresta
# Processing Record 19 of Set 14 | somerset
# Processing Record 20 of Set 14 | bindura
# Processing Record 21 of Set 14 | darhan
# Processing Record 22 of Set 14 | wakkanai
# Processing Record 23 of Set 14 | khasan
# Processing Record 24 of Set 14 | shiloh
# Processing Record 25 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 26 of Set 14 | richards bay
# Processing Record 27 of Set 14 | paidha
# Processing Record 28 of Set 14 | ekibastuz
# Processing Record 29 of Set 14 | den helder
# Processing Record 30 of Set 14 | terrace bay
# Processing Record 31 of Set 14 | gunjur
# Processing Record 32 of Set 14 | tessalit
# Processing Record 33 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 14 | mwense
# Processing Record 35 of Set 14 | bathsheba
# Processing Record 36 of Set 14 | hanzhong
# Processing Record 37 of Set 14 | kartarpur
# Processing Record 38 of Set 14 | juneau
# Processing Record 39 of Set 14 | seagoville
# Processing Record 40 of Set 14 | jaque
# Processing Record 41 of Set 14 | buala
# Processing Record 42 of Set 14 | areosa
# Processing Record 43 of Set 14 | tortosa
# Processing Record 44 of Set 14 | tammisaari
# Processing Record 45 of Set 14 | kalmunai
# Processing Record 46 of Set 14 | yar-sale
# Processing Record 47 of Set 14 | talcahuano
# Processing Record 48 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 49 of Set 14 | ceyhan
# Processing Record 50 of Set 14 | trincomalee
# Processing Record 1 of Set 15 | skowhegan
# Processing Record 2 of Set 15 | margate
# Processing Record 3 of Set 15 | srednekolymsk
# Processing Record 4 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 15 | gamboula
# Processing Record 6 of Set 15 | paka
# Processing Record 7 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 8 of Set 15 | flinders
# Processing Record 9 of Set 15 | bistret
# Processing Record 10 of Set 15 | zlobin
# Processing Record 11 of Set 15 | visnes
# Processing Record 12 of Set 15 | abu samrah
# Processing Record 13 of Set 15 | bubaque
# Processing Record 14 of Set 15 | tutoia
# Processing Record 15 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 15 | aracati
# Processing Record 18 of Set 15 | black forest
# Processing Record 19 of Set 15 | bilibino
# Processing Record 20 of Set 15 | lichinga
# Processing Record 21 of Set 15 | muncar
# Processing Record 22 of Set 15 | pakxan
# Processing Record 23 of Set 15 | kenora
# Processing Record 24 of Set 15 | taunggyi
# Processing Record 25 of Set 15 | peno
# Processing Record 26 of Set 15 | huazolotitlan
# City not found. Skipping...
# Processing Record 27 of Set 15 | marshfield
# Processing Record 28 of Set 15 | hirara
# Processing Record 29 of Set 15 | anloga
# Processing Record 30 of Set 15 | trairi
# Processing Record 31 of Set 15 | palotina
# Processing Record 32 of Set 15 | ambon
# Processing Record 33 of Set 15 | guiglo
# Processing Record 34 of Set 15 | port hawkesbury
# Processing Record 35 of Set 15 | san esteban
# Processing Record 36 of Set 15 | jaguarao
# Processing Record 37 of Set 15 | wewak
# Processing Record 38 of Set 15 | savannakhet
# Processing Record 39 of Set 15 | porbandar
# Processing Record 40 of Set 15 | san borja
# Processing Record 41 of Set 15 | muroto
# Processing Record 42 of Set 15 | sena madureira
# Processing Record 43 of Set 15 | mizpe ramon
# City not found. Skipping...
# Processing Record 44 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 15 | upata
# Processing Record 46 of Set 15 | lewistown
# Processing Record 47 of Set 15 | korla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Fontanka      UA  46.5626   30.8607     45.72        80          93
# 1            Ginda      IN  30.6945   78.4932     52.95        36           1
# 2  Bambous Virieux      MU -20.3428   57.7575     77.22       100          75
# 3       Manjeshwar      IN  12.7194   74.8861     76.15        83          52
# 4     Punta Arenas      CL -53.1500  -70.9167     46.51        76          40
# 5        Jamestown      US  42.0970  -79.2353     40.51        52         100
# 6       Bredasdorp      ZA -34.5322   20.0403     55.98        81           0
# 7           Milove      UA  49.3787   40.1302     48.33        74         100
# 8          Yeppoon      AU -23.1333  150.7333     78.58        61           2
# 9        Upernavik      GL  72.7868  -56.1549    -13.04        99          35
#
#    Wind Speed Current Description
# 0       16.55     overcast clouds
# 1        7.94           clear sky
# 2       11.50         shower rain
# 3        4.79       broken clouds
# 4       13.80    scattered clouds
# 5        8.05     overcast clouds
# 6        6.76           clear sky
# 7        9.91     overcast clouds
# 8       11.48           clear sky
# 9        9.24    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
